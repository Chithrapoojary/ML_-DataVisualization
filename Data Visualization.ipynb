# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snr

# %%
iris=snr.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# ## ***LINE GRAPH***

# %%
ax=iris.plot(figsize=(10,5),title='Iris Dataset')
ax.set_xlabel("x axis")
ax.set_ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %%
ax=iris.plot(figsize=(10,10),title="Iris Dataset")
ax.set_xlabel("x axis")
ax.set_ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %%
ax=iris['petal_length'].plot(figsize=(5,3),title='Iris Dataset')
ax.set_xlabel("x axis")
ax.set_ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %%
ax=iris['petal_width'].plot(figsize=(3,2),title='Isis Dataset')
ax.set_xlabel("x axis")
ax.set_ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
ax=iris['sepal_length'].plot(figsize=(5,5),title='Iris Dataset')
ax.set_xlabel("x axis")
ax.set_ylabel("y axis")
# Out:
# Text(0, 0.5, 'y axis')

# %%
ax=iris['sepal_width'].plot(figsize=(5,5),title='Iris Dataset')
ax.set_xlabel("x axis")
ax.set_xlabel("y axis")
# Out:
# Text(0.5, 0, 'y axis')

# %%
df=iris.drop(['species'],axis=1)

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %% [markdown]
# # ***BAR GRAPH***

# %%
df.plot(kind='bar')   #visualizing the entire rows
# Out:
# <Axes: >

# %%
df.plot(kind='barh')
# Out:
# <Axes: >

# %%
df.iloc[0].plot(kind='bar')   #visualizing 0th row
# Out:
# <Axes: >

# %%
df.iloc[15].plot(kind='barh')  #visualizing 15th row
# Out:
# <Axes: >

# %%
#visualize the 100th row and tell which column is having the 2nd highest value
df.iloc[100].plot(kind='bar')
# Out:
# <Axes: >

# %%
df.iloc[0:4].plot(kind='bar')
# Out:
# <Axes: >

# %%
df.iloc[100:104].plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ## ***HISTOGRAM***

# %%
df.plot(kind='hist',bins=200)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind='hist',bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['sepal_length'].diff().plot(kind='hist',bins=200)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['sepal_width'].diff().plot(kind='hist',bins=200)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['petal_width'].diff().plot(kind='hist',bins=200)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['petal_length'].diff().plot(kind='hist',bins=200)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## ***PEI CHART***

# %%
df.iloc[0].plot.pie(figsize=(5,5),fontsize=15,autopct='%.2f')
# Out:
# <Axes: ylabel='0'>

# %%
df.iloc[100].plot.pie(figsize=(10,10),fontsize=10,autopct='%.3f')
# Out:
# <Axes: ylabel='100'>

# %%
df.iloc[0:3].plot.pie(subplots=True,figsize=(10,10),fontsize=10,autopct='%.2f')
# Out:
# array([<Axes: ylabel='sepal_length'>, <Axes: ylabel='sepal_width'>,
#        <Axes: ylabel='petal_length'>, <Axes: ylabel='petal_width'>],
#       dtype=object)

# %%
df.iloc[0:3].plot.pie(subplots=True,figsize=(15,15),fontsize=10,autopct='%.2f')
# Out:
# array([<Axes: ylabel='sepal_length'>, <Axes: ylabel='sepal_width'>,
#        <Axes: ylabel='petal_length'>, <Axes: ylabel='petal_width'>],
#       dtype=object)

# %%
df.iloc[0:5].plot.pie(subplots=True,figsize=(15,15),fontsize=10,autopct='%.2f')
# Out:
# array([<Axes: ylabel='sepal_length'>, <Axes: ylabel='sepal_width'>,
#        <Axes: ylabel='petal_length'>, <Axes: ylabel='petal_width'>],
#       dtype=object)
